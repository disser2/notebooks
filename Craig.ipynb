# %% [markdown]
# # Hi Craig. Dies ist ein kleines Beispiel

# %% [markdown]
# Man kann Text und Code mischen. LaTeX geht natürlich auch \begin{align*}\sum_{i=1}^\infty i^2= 7\end{align*}

# %% [markdown]
# # Basic Imports

# %%
# Standard Libs
import numpy as np
import pandas as pd

# Machine Learning Libs
from sklearn import linear_model, svm, tree, cluster, manifold, datasets

# Plots
import pylab as pl
# %matplotlib inline

# %% [markdown]
# # Beispiel: Clustering

# %% [markdown]
# ## Rohdaten

# %%
X, y = datasets.make_blobs(n_samples=1000, centers=4, random_state=10)
pl.scatter(X[:, 0], X[:, 1])

# %% [markdown]
# ## Wir berechnen automatisch Cluster von Punkten

# %%
db = cluster.DBSCAN(eps=2, min_samples=5).fit(X)
colors = [int(i % 23) for i in db.labels_]
pl.scatter(X[:, 0], X[:, 1], c=colors)
